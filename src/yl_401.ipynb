# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# Setup complete ✅ (12 CPUs, 15.4 GB RAM, 104.0/467.3 GB disk)

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# ...
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# image 1/1 /home/jm/dev_ws/mldl/src/zidane.jpg: 384x640 2 persons, 1 tie, 62.1ms
# Speed: 3.9ms preprocess, 62.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /home/jm/dev_ws/mldl/src/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO
# Load a model
model = YOLO("yolov8n.pt")
# load a pretrained model (recommended for training)
# Use the model
model.train(data="coco8.yaml", epochs=3) # train the model
metrics = model.val() # evaluate model performance on the validation set
results = model("https://ultralytics.com/images/bus.jpg") # predict on an image
path = model.export(format="onnx") # export the model to ONNX format
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# ...

# %%
# !yolo predict model=runs/detect/train/weights/best.pt source='./bus.jpg'
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CPU (Intel Core i7-10750H 2.60GHz)
# Model summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /home/jm/dev_ws/mldl/src/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 101.6ms
# Speed: 4.1ms preprocess, 101.6ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /home/jm/dev_ws/mldl/src/runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=runs/detect/train/weights/best.pt source='./rugby.jpg'
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CPU (Intel Core i7-10750H 2.60GHz)
# Model summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /home/jm/dev_ws/mldl/src/rugby.jpg: 448x640 8 persons, 79.3ms
# Speed: 5.1ms preprocess, 79.3ms inference, 8.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /home/jm/dev_ws/mldl/src/runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=runs/detect/train/weights/best.pt source='./dogs.png'
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# Model summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /home/jm/dev_ws/mldl/src/dogs.png: 448x640 1 bird, 2 dogs, 1 sheep, 1 teddy bear, 60.5ms
# Speed: 2.1ms preprocess, 60.5ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /home/jm/dev_ws/mldl/src/runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=runs/detect/train/weights/best.pt source='./cars.jpeg'
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# Model summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /home/jm/dev_ws/mldl/src/cars.jpeg: 640x448 30 cars, 3 buss, 49.7ms
# Speed: 2.2ms preprocess, 49.7ms inference, 13.8ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to /home/jm/dev_ws/mldl/src/runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=runs/detect/train/weights/best.pt source='./robot.jpg'
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# Model summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /home/jm/dev_ws/mldl/src/robot.jpg: 480x640 15 persons, 1 car, 2 skateboards, 49.7ms
# Speed: 1.1ms preprocess, 49.7ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /home/jm/dev_ws/mldl/src/runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=runs/detect/train/weights/best.pt source='./train.jpg'
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# Model summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /home/jm/dev_ws/mldl/src/train.jpg: 352x640 1 train, 59.3ms
# Speed: 3.1ms preprocess, 59.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to /home/jm/dev_ws/mldl/src/runs/detect/predict7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=runs/detect/train/weights/best.pt source='./coach.webp'
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# Model summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /home/jm/dev_ws/mldl/src/coach.webp: 384x640 12 persons, 1 bottle, 1 wine glass, 2 chairs, 3 dining tables, 59.4ms
# Speed: 2.3ms preprocess, 59.4ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /home/jm/dev_ws/mldl/src/runs/detect/predict8
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
