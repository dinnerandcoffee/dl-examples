# %%
from ultralytics import YOLO
model = YOLO('yolov8n-cls.pt')
results = model.predict(source="./rock_scissor_paper/1.jpeg", save=True)
# Out:
# image 1/1 /home/jm/dev_ws/mldl/src/rock_scissor_paper/1.jpeg: 224x224 rubber_eraser 0.22, spatula 0.15, paintbrush 0.10, ice_lolly 0.05, plunger 0.04, 2.9ms
# Speed: 10.5ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /home/jm/dev_ws/mldl/src/runs/classify/predict10

# %%
model = YOLO('yolov8n-cls.pt')
results = model.train(data='./rock_scissor_paper', epochs=5, imgsz=640)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO('./runs/classify/train/weights/best.pt')
results = model.predict(source='rock_scissor_paper/1.jpeg', save=True)

# %%
from ultralytics import YOLO
model = YOLO('./runs/classify/train/weights/best.pt')
results = model.predict(source='rock_scissor_paper/2.jpeg', save=True)

# %%
from ultralytics import YOLO
model = YOLO('./runs/classify/train/weights/best.pt')
results = model.predict(source='rock_scissor_paper/3.jpeg', save=True)
