# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
results = mode.predict(source="./road.webp", conf=0.2, save=True)
print(results)
# Out:
# image 1/1 /home/jm/dev_ws/mldl/src/road.webp: 480x640 7 cars, 1 traffic light, 1 stop sign, 9.7ms
# Speed: 21.6ms preprocess, 9.7ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /home/jm/dev_ws/mldl/src/runs/detect/predict9
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n model       
results = model.train(data='aquarium/data.yaml', epochs=25, batch=4)  # train the model
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# ...
