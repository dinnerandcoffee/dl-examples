# %% [markdown]
# # YOLO 환경 준비 및 모델 로드
# Ultralytics YOLO 라이브러리 설치 및 사전학습된 모델을 불러옵니다.

# %%
#!pip install ultralytics
from ultralytics import YOLO

model=YOLO('yolov8n.pt')

# %% [markdown]
# # 커스텀 데이터셋으로 모델 학습
# YOLO 모델을 커스텀 데이터셋으로 학습합니다. 학습 epoch와 배치 크기를 지정합니다.

# %%
results = model.train(data='../data/Not Today/YOLODataset/dataset.yaml', epochs=1000, batch=16)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# ...

# %% [markdown]
# # 학습된 모델로 비디오 객체 탐지
# 학습된 YOLO 모델을 사용하여 비디오에서 객체를 탐지하고 결과를 화면에 표시합니다.

# %%
from ultralytics import YOLO
import cv2

model = YOLO("./runs/detect/train14/weights/best.pt")

# source = "https://youtu.be/DvrvoQmh5fw"  # YouTube (연결 불안정할 수 있음)
# source = 0  # 웹캠 사용 (0 = 기본 웹캠)
source = "../data/Not Today.mp4"  # 로컬 비디오 파일

model.predict(source=source, show=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/6964) /home/jm/dev_ws/mldl/src/../data/Not Today.mp4: 384x640 (no detections), 7.6ms
# video 1/1 (frame 2/6964) /home/jm/dev_ws/mldl/src/../data/Not Today.mp4: 384x640 (no detections), 5.9ms
# video 1/1 (frame 3/6964) /home/jm/dev_ws/mldl/src/../data/Not Today.mp4: 384x640 (no detections), 6.8ms
# video 1/1 (frame 4/6964) /home/jm/dev_ws/mldl/src/../data/Not Today.mp4: 384x640 (no detections), 6.9ms
# ...
