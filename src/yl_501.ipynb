# %%
# !yolo segment predict model=yolov8n-seg.pt source='https://ultralytics.com/images/bus.jpg' save=True show=True conf=0.25
# Out:
# ...
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,404,320 parameters, 0 gradients, 12.0 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /home/jm/dev_ws/mldl/src/bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 62.1ms
# Speed: 2.2ms preprocess, 62.1ms inference, 20.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /home/jm/dev_ws/mldl/src/runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO
model = YOLO('yolov8n-seg.pt')
results = model.predict(source='https://ultralytics.com/images/zidane.jpg', conf=0.25, save=True, show=True)
results
# Out:
# Found https://ultralytics.com/images/zidane.jpg locally at zidane.jpg
# image 1/1 /home/jm/dev_ws/mldl/src/zidane.jpg: 384x640 2 persons, 1 tie, 59.7ms
# Speed: 2.9ms preprocess, 59.7ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /home/jm/dev_ws/mldl/src/runs/segment/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...
