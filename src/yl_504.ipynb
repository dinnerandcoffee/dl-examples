# %%
from ultralytics import YOLO

model = YOLO('yolov8n-pose.pt')
source = 'https://ultralytics.com/images/bus.jpg'  # Replace with your video or image path
results = model(source=source, show=True, save=True)
# Out:
# ...
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /home/jm/dev_ws/mldl/src/bus.jpg: 640x480 4 persons, 49.5ms
# Speed: 4.6ms preprocess, 49.5ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /home/jm/dev_ws/mldl/src/runs/pose/predict

# %%
results = model.train(data='coco8-pose.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# ...

# %%
from ultralytics import YOLO

mode = YOLO('yolov8n-pose.pt')
model(source='../data/people_walk.mp4', save=True, imgsz=1280)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/341) /home/jm/dev_ws/mldl/src/../data/people_walk.mp4: 736x1280 27 persons, 39.8ms
# video 1/1 (frame 2/341) /home/jm/dev_ws/mldl/src/../data/people_walk.mp4: 736x1280 29 persons, 12.2ms
# video 1/1 (frame 3/341) /home/jm/dev_ws/mldl/src/../data/people_walk.mp4: 736x1280 29 persons, 12.3ms
# video 1/1 (frame 4/341) /home/jm/dev_ws/mldl/src/../data/people_walk.mp4: 736x1280 28 persons, 12.3ms
# ...
